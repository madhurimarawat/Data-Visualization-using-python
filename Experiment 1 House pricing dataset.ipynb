# %%
# Experiment 1
# Download the House pricing dataset from kaggle and map the value to Aesthetics.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/Housing.csv")

# %%
#Printing the dataset
print(df)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.scatterplot(y='area',x='price',data=df)
plt.title("Scatter Plot showing Area and Price of house")
plt.ylabel("Area of the House")
plt.xlabel("Price of the House")
# Out:
# Text(0.5, 0, 'Price of the House')

# %%
sns.scatterplot(x='area',y='price',data=df)
plt.title("Scatter Plot showing Area and Price of house")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.scatterplot(x='area',y='price',data=df,hue=df["mainroad"])
plt.title("Area and Price of house with Mainroad")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.lineplot(x='area',y='price',data=df,hue=df["mainroad"])
plt.title("Area and Price of house with Mainroad")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.pointplot(x='area',y='price',data=df,hue=df["mainroad"])
plt.title("Area and Price of house with Mainroad")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.swarmplot(x='area',y='price',data=df,hue=df["mainroad"])
plt.title("Area and Price of house with Mainroad")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pointplot(x='area',y='price',data=df,hue=df["guestroom"])
plt.title("Area and Price of house with Guestroom")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.swarmplot(x='area',y='price',data=df,hue=df["guestroom"])
plt.title("Area and Price of house with Guestroom")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.barplot(x='area',y='price',data=df)
plt.title("Bar Plot showing Area and Price of house")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.boxplot(x='area',y='price',data=df)
plt.title("Box Plot showing Area and Price of house")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.violinplot(x='area',y='price',data=df)
plt.title("Violin Plot showing Area and Price of house")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(0, 0.5, 'Price of the House')

# %%
sns.pairplot(df)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
sns.relplot(x='area',y='price',data=df,hue=df['parking'])
plt.title("Area and Price of house with Parking")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(37.481714506172835, 0.5, 'Price of the House')

# %%
sns.relplot(x='area',y='price',data=df,hue=df['mainroad'])
plt.title("Area and Price of house with Mainroad")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(39.25464506172838, 0.5, 'Price of the House')

# %%
sns.relplot(x='area',y='price',data=df,hue=df['guestroom'])
plt.title("Area and Price of house with Guestroom")
plt.xlabel("Area of the House")
plt.ylabel("Price of the House")
# Out:
# Text(40.38136728395061, 0.5, 'Price of the House')
