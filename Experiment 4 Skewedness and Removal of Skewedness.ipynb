# %%
# Experiment 4
# Show an example of skewed data and removal of skewedness

# %%
# Importing random module to generate data
from random import *

# %%
r1=[random() for i in range(1000)]

# %%
# Importing seaborn for data visualization
import seaborn as sns
# Plotting histogram
sns.histplot(r1)
# Out:
# <Axes: ylabel='Count'>

# %%
# Generating gaussian data
r2=[gauss(1,1) for i in range(10000)]
# Plotting histogram
sns.histplot(r2)
# Out:
# <Axes: ylabel='Count'>

# %%
# Generating triangular data
r3=[triangular(1,100) for i in range(10000)]
# Plotting histogram
sns.histplot(r3)
# Out:
# <Axes: ylabel='Count'>

# %%
# Generating triangular data
r3=[triangular(1,100,80) for i in range(10000)]
# Plotting histogram
sns.histplot(r3)
# Out:
# <Axes: ylabel='Count'>

# %%
# Plotting scatter plot will be useless as due to many data points it will look like collection of points
sns.scatterplot(r3)
# Out:
# <Axes: >

# %%
# Generating triangular data
r4=[triangular(1,100,10) for i in range(10000)]
# Plotting histogram
sns.histplot(r4)
# Out:
# <Axes: ylabel='Count'>

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Generate skewed data
data = np.random.gamma(1, 3, 1000)

# Plot histogram to visualize skewness
plt.hist(data, bins=50)
plt.title("Skewed Data Histogram")
plt.show()

# Calculate skewness of data
skewness = stats.skew(data)
print("Skewness:", skewness)

# Apply log transformation to reduce skewness
log_data = np.log(data)

# Plot histogram of transformed data
plt.hist(log_data, bins=50)
plt.title("Transformed Data Histogram")
plt.show()

# Calculate skewness of transformed data
log_skewness = stats.skew(log_data)
print("Transformed Skewness:", log_skewness)
# Out:
# Skewness: 1.8860715563392059
# Transformed Skewness: -0.9126850303977643
